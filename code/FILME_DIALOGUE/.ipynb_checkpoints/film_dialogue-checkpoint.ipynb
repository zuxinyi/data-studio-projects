# %%
import pandas as pd
# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c1ef5c3d10e4> in <module>()
# ----> 1 import pandas as pd
#       2 get_ipython().magic('matplotlib inline')
#       3 matplotlib.rcParams['pdf.fonttype'] = 42
#
# ModuleNotFoundError: No module named 'pandas'

# %%
character_list = pd.read_csv('character_list5.csv', encoding = "Latin1").head(1148)
character_list.groupby('gender')['words'].sum()
# Out:
# gender
# f    178933
# m    625024
# Name: words, dtype: int64

# %%
character_list.head()
# Out:
#    script_id imdb_character_name  words gender   age
# 0        280               betty    311      f  35.0
# 1        280     carolyn johnson    873      f   NaN
# 2        280             eleanor    138      f   NaN
# 3        280     francesca johns   2251      f  46.0
# 4        280               madge    190      f  46.0

# %%
character_list[character_list.age.notnull()].groupby('gender')['age'].mean()
# Out:
# gender
# f    35.727679
# m    43.382876
# Name: age, dtype: float64

# %%
character_list['gender'].value_counts()
# Out:
# m    843
# f    305
# Name: gender, dtype: int64

# %%
character_list['script_id'].value_counts()
# Out:
# 745    23
# 665    22
# 734    22
# 701    21
# 795    21
# 761    21
# 855    20
# 716    19
# 664    19
# 901    18
# 806    17
# 830    16
# 809    16
# 650    16
# 647    16
# 653    16
# 666    16
# 866    15
# 757    15
# 630    15
# 871    15
# 793    15
# 707    15
# 706    15
# 759    14
# 771    14
# 774    14
# 822    14
# 808    14
# 678    14
#        ..
# 779    10
# 781    10
# 878    10
# 726    10
# 740    10
# 768     9
# 850     9
# 718     9
# 674     9
# 625     9
# 682     9
# 864     9
# 676     8
# 909     8
# 722     8
# 744     8
# 851     8
# 869     8
# 729     7
# 789     7
# 813     7
# 898     7
# 280     7
# 699     6
# 712     6
# 725     6
# 848     6
# 863     6
# 832     5
# 873     3
# Name: script_id, Length: 94, dtype: int64

# %%
import matplotlib.pyplot as plt
percent = character_list.groupby('script_id')['gender'].value_counts(normalize = True,sort=False)
percent
# Out:
# script_id  gender
# 280        f         0.714286
#            m         0.285714
# 623        f         0.285714
#            m         0.714286
# 625        f         0.111111
#            m         0.888889
# 630        f         0.133333
#            m         0.866667
# 633        f         0.285714
#            m         0.714286
# 640        f         0.153846
#            m         0.846154
# 642        f         0.307692
#            m         0.692308
# 647        f         0.250000
#            m         0.750000
# 648        f         0.300000
#            m         0.700000
# 650        f         0.250000
#            m         0.750000
# 652        f         0.166667
#            m         0.833333
# 653        f         0.125000
#            m         0.875000
# 664        f         0.263158
#            m         0.736842
# 665        f         0.227273
#            m         0.772727
# 666        f         0.375000
#            m         0.625000
# ...

# %%
female_words = character_list[character_list.gender == 'f'].groupby('script_id')['words'].sum().reset_index()
male_words = character_list[character_list.gender == 'm'].groupby('script_id')['words'].sum().reset_index()
female_words.columns = ['script_id', 'female_words']
male_words.columns = ['script_id', 'male_words']
movie_words = female_words.merge(male_words, how = 'left', on = 'script_id')

# %%
movie_words
# Out:
#     script_id  female_words  male_words
# 0         280          3763        2631
# 1         623          1524        7584
# 2         625           155        4246
# 3         630          1073        9059
# 4         633           866        8163
# 5         640           879        5253
# 6         642          1317        6527
# 7         647          1492        4679
# 8         648          1500        3984
# 9         650          1704        4138
# 10        652           349        5888
# 11        653           857        8144
# 12        664          2266       10022
# 13        665           939        8100
# 14        666          2619        7255
# 15        674          1298        5018
# 16        676          2148        3003
# 17        678           759       12083
# 18        682          4142        8994
# 19        697          1141        8977
# 20        698          1714        3779
# 21        699           940        3494
# ...

# %%
female = []
male = []
for x in range(0, len(percent)):
    if x%2 == 0:
        female.append(percent[x])
    else:
        male.append(percent[x])

# %% [markdown]
# gender = []
# for x,y in zip(female,male):
#     row = [x,y]
#     gender.append(row)
#
# df_gender = pd.DataFrame(gender, columns=['female','male'])
# df_gender

# %%
character_count = character_list.groupby('script_id')['gender'].size().reset_index()
character_count['female'] = female
character_count['male'] = 1 - character_count['female']

# %%
character_count
# Out:
#     script_id  gender    female      male
# 0         280       7  0.714286  0.285714
# 1         623      14  0.285714  0.714286
# 2         625       9  0.111111  0.888889
# 3         630      15  0.133333  0.866667
# 4         633      14  0.285714  0.714286
# 5         640      13  0.153846  0.846154
# 6         642      13  0.307692  0.692308
# 7         647      16  0.250000  0.750000
# 8         648      10  0.300000  0.700000
# 9         650      16  0.250000  0.750000
# 10        652      12  0.166667  0.833333
# 11        653      16  0.125000  0.875000
# 12        664      19  0.263158  0.736842
# 13        665      22  0.227273  0.772727
# 14        666      16  0.375000  0.625000
# 15        674       9  0.333333  0.666667
# 16        676       8  0.500000  0.500000
# 17        678      14  0.071429  0.928571
# 18        682       9  0.444444  0.555556
# 19        697      10  0.300000  0.700000
# 20        698      10  0.500000  0.500000
# ...

# %%
movies_info.sort_values(by = 'year')
movies_info=movies_info.rename(columns = {'female_words_x':'Female Words'})
movies_info=movies_info.rename(columns = {'male_words_x':'Male Words'})
import matplotlib
matplotlib.style.use('ggplot')
ax = movies_info['Female Words'].plot(figsize = (25,20))
movies_info['Male Words'].plot(ax = ax)
plt.savefig('graph1.pdf')

# %%
movies_info.sort_values(by='year').reset_index()
# Out:
#     index  script_id  gender    female      male    imdb_id  \
# 0      82        873       3  0.333333  0.666667  tt0023969
# 1      55        808      14  0.142857  0.857143  tt0033467
# 2      80        869       8  0.250000  0.750000  tt0036775
# 3      69        849      11  0.090909  0.909091  tt0043456
# 4      22        701      21  0.333333  0.666667  tt0053619
# 5      53        805      12  0.250000  0.750000  tt0059037
# 6       2        625       9  0.111111  0.888889  tt0062622
# 7      67        846      14  0.071429  0.928571  tt0068451
# 8      14        666      16  0.375000  0.625000  tt0069704
# 9      29        716      19  0.210526  0.789474  tt0072684
# 10     77        864       9  0.333333  0.666667  tt0072890
# 11     18        682       9  0.444444  0.555556  tt0075686
# 12     73        853      11  0.181818  0.818182  tt0077416
# 13     68        848       6  0.333333  0.666667  tt0077405
# 14      8        648      10  0.300000  0.700000  tt0080339
# ...

# %%
info = pd.read_csv('Public Script Sources - public_scripts.csv')
movies_info = character_count.merge(info, how = 'left',on = 'script_id')
movies_1970 = movies_info[movies_info['year'] < 1970]

# %%
matplotlib.style.use('ggplot')
ax = movies_1970.plot(kind='bar',x = 'imdb_id', y = 'female', width = 0.3, color = 'red', position=1)
movies_1970.plot(kind='bar',ax = ax, x = 'imdb_id', y = 'male', width = 0.3, color = 'green',position = 0)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    left= 'off') 

ax.set_ylabel('percentage')
ax.set_xlabel('')
ax.set_title('Female character vs Male character before 1970')

# %%
import matplotlib
matplotlib.style.use('ggplot')
df4 = pd.DataFrame({'female': [1,2,4], 'male': [2,5,7] }, columns=['female', 'male'])
df4
#plt.figure();

df4.plot.hist(alpha=0.5)

# %%
print(plt.style.available)
# Out:
# ['seaborn-deep', 'seaborn-dark-palette', 'fivethirtyeight', 'seaborn-bright', 'seaborn-darkgrid', 'seaborn-whitegrid', 'seaborn-paper', 'seaborn-dark', 'seaborn-muted', 'dark_background', 'seaborn-ticks', 'seaborn-notebook', 'seaborn-pastel', 'seaborn-talk', '_classic_test', 'seaborn-poster', 'seaborn-colorblind', 'seaborn-white', 'seaborn', 'ggplot', 'grayscale', 'bmh', 'classic']

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import matplotlib
matplotlib.style.use('ggplot')

percent = [['< 1970',0.784065141208,0.215934858792],
['1970s',0.721445117122,0.278554882878],
['1980s',0.751233853865,0.248766146135],
['1990s',0.59777603349,0.40222396651],
['2000s',0.781648113791,0.218351886209]]

df2 = pd.DataFrame(percent, columns=['year','male', 'female'])
df2.set_index('year',inplace= True)
plt.figure()
df2.plot.bar(figsize = (25,20),stacked=True)
#plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig('graph2.pdf')

# %%
print(movies_2010['male'].mean())
print(movies_2010['female'].mean())
# Out:
# 0.781648113791
# 0.218351886209

# %%
import matplotlib
matplotlib.style.use('ggplot')

movies_1980 = movies_info[(movies_info['year'] > 1970) & (movies_info['year'] < 1980) ]
matplotlib.style.use('fivethirtyeight')
ax2 = movies_1980.plot(figsize= (25,20),kind='bar',x = 'imdb_id', y = 'female', width = 0.3, color = 'red', position=1)
movies_1980.plot(kind='bar',ax = ax2, x = 'imdb_id', y = 'male', width = 0.3, color = 'green',position = 0)

ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax2.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    left= 'off') 

ax2.set_ylabel('percentage')
ax2.set_xlabel('')
ax2.set_title('Female character vs Male character in 1970s')
plt.savefig('graph7.pdf')

# %%
matplotlib.style.use('ggplot')
movies_1990 = movies_info[(movies_info['year'] > 1980) & (movies_info['year'] < 1990)]#.head(7)
ax3 = movies_1990.plot(figsize= (25,20),kind='bar',x = 'imdb_id', y = 'female', width = 0.3, color = 'red', position=1)
movies_1990.plot(kind='bar',ax = ax3, x = 'imdb_id', y = 'male', width = 0.3, color = 'green',position = 0)

ax3.spines['top'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['right'].set_visible(False)

ax3.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    left= 'off') 

ax3.set_ylabel('percentage')
ax3.set_xlabel('')
ax3.set_title('Female character vs Male character in 1980s')
plt.savefig('graph4.pdf')

# %%
matplotlib.style.use('ggplot')
movies_2000 = movies_info[(movies_info['year'] > 1990) & (movies_info['year'] < 2000)].head(15)
ax4 = movies_2000.plot(figsize=(30,25),kind='bar',x = 'imdb_id', y = 'female', width = 0.25, color = 'red', position=1)
movies_2000.plot(kind='bar',ax = ax4, x = 'imdb_id', y = 'male', width = 0.25, color = 'green',position = 0)

ax4.spines['top'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['right'].set_visible(False)

ax4.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    left= 'off') 

ax4.set_ylabel('percentage')
ax4.set_xlabel('')
ax4.set_title('Female character vs Male character in 1990')
plt.savefig('graph5.pdf')

# %%
matplotlib.style.use('ggplot')
movies_2010 = movies_info[(movies_info['year'] > 2000) & (movies_info['year'] < 2010)].head(15)
ax5 = movies_2010.plot(figsize=(25,20),kind='bar',x = 'imdb_id', y = 'female', width = 0.25, color = 'red', position=1)
movies_2010.plot(kind='bar',ax = ax5, x = 'imdb_id', y = 'male', width = 0.25, color = 'green',position = 0)

ax5.spines['top'].set_visible(False)
ax5.spines['left'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['right'].set_visible(False)

ax5.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    left= 'off') 

ax5.set_ylabel('percentage')
ax5.set_xlabel('')
ax5.set_title('Female character vs Male character in 2000s')
plt.savefig('graph6.pdf')

# %%
character_mapping = pd.read_csv('character_mapping.csv', encoding = "Latin1")
character_mapping.head()
# Out:
#    script_id    imdb_id character_from_script  \
# 0          1  tt0147800                bianca
# 1          1  tt0147800               cameron
# 2          1  tt0147800              chastity
# 3          1  tt0147800                  joey
# 4          1  tt0147800                   kat
#
#   closest_character_name_from_imdb_match closest_imdb_character_id
# 0                       bianca stratford                 nm0646351
# 1                          cameron james                 nm0330687
# 2                               chastity                 nm0005517
# 3                            joey donner                 nm0005080
# 4                          kat stratford                 nm0005466

# %%
character_mapping.groupby('script_id')['character_from_script'].value_counts()
# Out:
# script_id  character_from_script
# 1          bianca                   1
#            cameron                  1
#            chastity                 1
#            joey                     1
#            kat                      1
#            mandella                 1
#            michael                  1
#            patrick                  1
#            walter                   1
# 2          alonso                   1
#            arojaz                   1
#            beatrix                  1
#            bobadilla                1
#            columbus                 1
#            fernando                 1
#            isabel                   1
#            marchena                 1
#            mendez                   1
#            moxica                   1
#            pinzon                   1
#            sanchez                  1
#            utapan                   1
# 3          cutler                   1
#            daphne                   1
# ...

# %%
meta_data = pd.read_csv('meta_data7.csv', encoding = "Latin1")
meta_data['lines_data'].head(5)
# Out:
# 0    7435445256774774443342577775657744434444564456...
# 1    1777752320274533344457777722433777334443764677...
# 2    5461357777754212454544441367774433446547647753...
# 3    4567334777777777777777447777756477777444777777...
# 4                       453513352345765766777777773340
# Name: lines_data, dtype: object

# %%
meta_data#[meta_data.script_id == 100]
# Out:
#       script_id    imdb_id                        title  year  gross  \
# 0          1534  tt1022603         (500) Days of Summer  2009   37.0
# 1          1512  tt0147800   10 Things I Hate About You  1999   65.0
# 2          1514  tt0417385               12 and Holding  2005    NaN
# 3          1517  tt2024544             12 Years a Slave  2013   60.0
# 4          1520  tt1542344                    127 Hours  2010   20.0
# 5          6537  tt0450385                         1408  2007   91.0
# 6          3778  tt0103594   1492: Conquest of Paradise  1992   15.0
# 7           623  tt0179626                   15 Minutes  2001   37.0
# 8          1525  tt0974661                     17 Again  2009   74.0
# 9          6030  tt1272878                       2 Guns  2013   80.0
# 10          625  tt0062622        2001: A Space Odyssey  1968  376.0
# 11         1509  tt1190080                         2012  2009  192.0
# 12         8543  tt0478087                           21  2008   98.0
# ...

# %%
scrape_id = 'scrape_id'
title = 'title'
source = 'source'
year = 'year'
link = 'link'
imsdbCharsFile = 'imsdbCharsFile'
imdb_match = 'imdb_match'
cornellId = 'cornellId'
with open('movie.txt') as file:
    exec('movie ='+file.read())

# %%
df_movie = pd.DataFrame(movie).transpose().reset_index()

# %%
df_movie[df_movie.title == 'Hellraiser']
# Out:
#      index cornellId imdb_match    imsdbCharsFile  \
# 10    1007       NaN  tt0093177  Hellraiser.chars
# 1622  2519       NaN  tt0093177               NaN
# 1624  2520       NaN  tt0093177               NaN
# 1625  2521       NaN  tt0093177               NaN
# 3516  4347       m87  tt0093177               NaN
#
#                                                    link scrape_id  source  \
# 10     film_20100519/all_imsdb_05_19_10/Hellraiser.html      1007   imsdb
# 1622  http://www.imsdb.com/Movie Scripts/Hellraiser ...      2519  manual
# 1624  http://www.dailyscript.com/scripts/hellraiser_...      2520  manual
# 1625  http://www.dailyscript.com/scripts/hellraiser_...      2521  manual
# 3516  http://www.dailyscript.com/scripts/Hellraiser.txt      4347  manual
#
#            title  year
# 10    Hellraiser  NULL
# 1622  Hellraiser  NULL
# 1624  Hellraiser  NULL
# 1625  Hellraiser  NULL
# 3516  Hellraiser  NULL

# %%
movie_info = df_movie.merge(meta_data, how='inner', on = 'title')

# %%
movie_info
# Out:
#      index cornellId imdb_match                               imsdbCharsFile  \
# 0     1001       NaN  tt0252503                                  Heist.chars
# 1     2512       NaN  tt0252503                                          NaN
# 2     2513       NaN  tt0252503                                          NaN
# 3     1003       NaN  tt0167190                                Hellboy.chars
# 4     2516       NaN  tt0167190                                          NaN
# 5     2517       m86  tt0167190                                          NaN
# 6     1004       NaN  tt0337636                      Hellraiser-Deader.chars
# 7     2523       NaN  tt0337636                                          NaN
# 8     2524       NaN  tt0337636                                          NaN
# 9     2525       NaN  tt0337636                                          NaN
# 10    1005       NaN  tt0274546                  Hellraiser-Hellseeker.chars
# ...
